# %%
import pandas as pd

# %%
df = pd.read_csv("tesla_2018_to_2020.csv")
pd.option_context('display.max_rows', None)

# %%
df
# Out:
#          Unnamed: 0                 created_at               id_str  \
# 0                 0  2020-06-01T22:59:51+00:00  1267591722126598144
# 1                 1  2020-06-01T22:59:49+00:00  1267591711905026048
# 2                 2  2020-06-01T22:58:40+00:00  1267591424628973574
# 3                 3  2020-06-01T22:58:21+00:00  1267591344299683841
# 4                 4  2020-06-01T22:57:35+00:00  1267591151487418372
# ...             ...                        ...                  ...
# 3273942      840674  2018-06-01T21:04:20+00:00  1002657120527966208
# 3273943      840678  2018-06-01T21:02:59+00:00  1002656781955317760
# 3273944      840859  2018-06-01T19:59:13+00:00  1002640730899210240
# 3273945      840873  2018-06-01T19:53:19+00:00  1002639248602722304
# 3273946      840977  2018-06-01T19:07:27+00:00  1002627705219584000
#
#          conversation_id_str  \
# 0        1267591722126598144
# 1        1267591711905026048
# 2        1267591424628973574
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3273947 entries, 0 to 3273946
# Data columns (total 25 columns):
#  #   Column                     Dtype
# ---  ------                     -----
#  0   Unnamed: 0                 int64
#  1   created_at                 object
#  2   id_str                     int64
#  3   conversation_id_str        int64
#  4   full_text                  object
#  5   lang                       object
#  6   favorited                  bool
#  7   retweeted                  bool
#  8   retweet_count              int64
#  9   favorite_count             int64
#  10  reply_count                int64
#  11  quote_count                int64
#  12  quoted_status_id_str       float64
#  13  quoted_status_short_url    float64
#  14  quoted_status_expand_url   float64
#  15  user_id_str                int64
#  16  user_name                  object
#  17  user_full_name             object
#  18  user_verified              bool
# ...

# %%
df = df.drop_duplicates()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3273947 entries, 0 to 3273946
# Data columns (total 25 columns):
#  #   Column                     Dtype
# ---  ------                     -----
#  0   Unnamed: 0                 int64
#  1   created_at                 object
#  2   id_str                     int64
#  3   conversation_id_str        int64
#  4   full_text                  object
#  5   lang                       object
#  6   favorited                  bool
#  7   retweeted                  bool
#  8   retweet_count              int64
#  9   favorite_count             int64
#  10  reply_count                int64
#  11  quote_count                int64
#  12  quoted_status_id_str       float64
#  13  quoted_status_short_url    float64
#  14  quoted_status_expand_url   float64
#  15  user_id_str                int64
#  16  user_name                  object
#  17  user_full_name             object
#  18  user_verified              bool
# ...

# %%
df = df.drop(['favorited','retweeted','retweet_count','favorite_count','reply_count'], axis=1)

# %%
df
# Out:
#          Unnamed: 0                 created_at               id_str  \
# 0                 0  2020-06-01T22:59:51+00:00  1267591722126598144
# 1                 1  2020-06-01T22:59:49+00:00  1267591711905026048
# 2                 2  2020-06-01T22:58:40+00:00  1267591424628973574
# 3                 3  2020-06-01T22:58:21+00:00  1267591344299683841
# 4                 4  2020-06-01T22:57:35+00:00  1267591151487418372
# ...             ...                        ...                  ...
# 3273942      840674  2018-06-01T21:04:20+00:00  1002657120527966208
# 3273943      840678  2018-06-01T21:02:59+00:00  1002656781955317760
# 3273944      840859  2018-06-01T19:59:13+00:00  1002640730899210240
# 3273945      840873  2018-06-01T19:53:19+00:00  1002639248602722304
# 3273946      840977  2018-06-01T19:07:27+00:00  1002627705219584000
#
#          conversation_id_str  \
# 0        1267591722126598144
# 1        1267591711905026048
# 2        1267591424628973574
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3273947 entries, 0 to 3273946
# Data columns (total 20 columns):
#  #   Column                     Dtype
# ---  ------                     -----
#  0   Unnamed: 0                 int64
#  1   created_at                 object
#  2   id_str                     int64
#  3   conversation_id_str        int64
#  4   full_text                  object
#  5   lang                       object
#  6   quote_count                int64
#  7   quoted_status_id_str       float64
#  8   quoted_status_short_url    float64
#  9   quoted_status_expand_url   float64
#  10  user_id_str                int64
#  11  user_name                  object
#  12  user_full_name             object
#  13  user_verified              bool
#  14  in_reply_to_status_id_str  float64
#  15  in_reply_to_user_id_str    float64
#  16  hashtags                   object
#  17  mentions                   object
#  18  urls                       object
# ...

# %%
df = df.drop(['quote_count','quoted_status_id_str','quoted_status_short_url','quoted_status_expand_url','in_reply_to_status_id_str','in_reply_to_user_id_str'], axis=1)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3273947 entries, 0 to 3273946
# Data columns (total 14 columns):
#  #   Column               Dtype
# ---  ------               -----
#  0   Unnamed: 0           int64
#  1   created_at           object
#  2   id_str               int64
#  3   conversation_id_str  int64
#  4   full_text            object
#  5   lang                 object
#  6   user_id_str          int64
#  7   user_name            object
#  8   user_full_name       object
#  9   user_verified        bool
#  10  hashtags             object
#  11  mentions             object
#  12  urls                 object
#  13  media                object
# dtypes: bool(1), int64(4), object(9)
# memory usage: 352.8+ MB

# %%
df
# Out:
#          Unnamed: 0                 created_at               id_str  \
# 0                 0  2020-06-01T22:59:51+00:00  1267591722126598144
# 1                 1  2020-06-01T22:59:49+00:00  1267591711905026048
# 2                 2  2020-06-01T22:58:40+00:00  1267591424628973574
# 3                 3  2020-06-01T22:58:21+00:00  1267591344299683841
# 4                 4  2020-06-01T22:57:35+00:00  1267591151487418372
# ...             ...                        ...                  ...
# 3273942      840674  2018-06-01T21:04:20+00:00  1002657120527966208
# 3273943      840678  2018-06-01T21:02:59+00:00  1002656781955317760
# 3273944      840859  2018-06-01T19:59:13+00:00  1002640730899210240
# 3273945      840873  2018-06-01T19:53:19+00:00  1002639248602722304
# 3273946      840977  2018-06-01T19:07:27+00:00  1002627705219584000
#
#          conversation_id_str  \
# 0        1267591722126598144
# 1        1267591711905026048
# 2        1267591424628973574
# ...

# %%
df1 = df.iloc[: , 1:]

# %%
df1
# Out:
#                         created_at               id_str  conversation_id_str  \
# 0        2020-06-01T22:59:51+00:00  1267591722126598144  1267591722126598144
# 1        2020-06-01T22:59:49+00:00  1267591711905026048  1267591711905026048
# 2        2020-06-01T22:58:40+00:00  1267591424628973574  1267591424628973574
# 3        2020-06-01T22:58:21+00:00  1267591344299683841  1267591344299683841
# 4        2020-06-01T22:57:35+00:00  1267591151487418372  1267591151487418372
# ...                            ...                  ...                  ...
# 3273942  2018-06-01T21:04:20+00:00  1002657120527966208  1002657120527966208
# 3273943  2018-06-01T21:02:59+00:00  1002656781955317760  1002656781955317760
# 3273944  2018-06-01T19:59:13+00:00  1002640730899210240  1002640730899210240
# 3273945  2018-06-01T19:53:19+00:00  1002639248602722304  1002639248602722304
# 3273946  2018-06-01T19:07:27+00:00  1002627705219584000  1002627705219584000
#
# ...

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3273947 entries, 0 to 3273946
# Data columns (total 13 columns):
#  #   Column               Dtype
# ---  ------               -----
#  0   created_at           object
#  1   id_str               int64
#  2   conversation_id_str  int64
#  3   full_text            object
#  4   lang                 object
#  5   user_id_str          int64
#  6   user_name            object
#  7   user_full_name       object
#  8   user_verified        bool
#  9   hashtags             object
#  10  mentions             object
#  11  urls                 object
#  12  media                object
# dtypes: bool(1), int64(3), object(9)
# memory usage: 327.8+ MB

# %%
for a in (df['id_str'] == df1['conversation_id_str']):
    if(a==False): 
        print("False")
        break

# %%
df1 = df1.drop(['conversation_id_str'], axis=1)

# %%
df1
# Out:
#                         created_at               id_str  \
# 0        2020-06-01T22:59:51+00:00  1267591722126598144
# 1        2020-06-01T22:59:49+00:00  1267591711905026048
# 2        2020-06-01T22:58:40+00:00  1267591424628973574
# 3        2020-06-01T22:58:21+00:00  1267591344299683841
# 4        2020-06-01T22:57:35+00:00  1267591151487418372
# ...                            ...                  ...
# 3273942  2018-06-01T21:04:20+00:00  1002657120527966208
# 3273943  2018-06-01T21:02:59+00:00  1002656781955317760
# 3273944  2018-06-01T19:59:13+00:00  1002640730899210240
# 3273945  2018-06-01T19:53:19+00:00  1002639248602722304
# 3273946  2018-06-01T19:07:27+00:00  1002627705219584000
#
#                                                  full_text lang  \
# 0                  I just got hired at Tesla! God is good.   en
# 1        tesla [mergrim mix] (Remastered 2020) - Spangl...   en
# 2        Tesla - Little Suzi https://t.co/9Lj4jvF8KR vi...   en
# ...

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3273947 entries, 0 to 3273946
# Data columns (total 12 columns):
#  #   Column          Dtype
# ---  ------          -----
#  0   created_at      object
#  1   id_str          int64
#  2   full_text       object
#  3   lang            object
#  4   user_id_str     int64
#  5   user_name       object
#  6   user_full_name  object
#  7   user_verified   bool
#  8   hashtags        object
#  9   mentions        object
#  10  urls            object
#  11  media           object
# dtypes: bool(1), int64(2), object(9)
# memory usage: 302.9+ MB

# %%
df1 = df1.drop(['user_id_str'], axis=1)

# %%
df1
# Out:
#                         created_at               id_str  \
# 0        2020-06-01T22:59:51+00:00  1267591722126598144
# 1        2020-06-01T22:59:49+00:00  1267591711905026048
# 2        2020-06-01T22:58:40+00:00  1267591424628973574
# 3        2020-06-01T22:58:21+00:00  1267591344299683841
# 4        2020-06-01T22:57:35+00:00  1267591151487418372
# ...                            ...                  ...
# 3273942  2018-06-01T21:04:20+00:00  1002657120527966208
# 3273943  2018-06-01T21:02:59+00:00  1002656781955317760
# 3273944  2018-06-01T19:59:13+00:00  1002640730899210240
# 3273945  2018-06-01T19:53:19+00:00  1002639248602722304
# 3273946  2018-06-01T19:07:27+00:00  1002627705219584000
#
#                                                  full_text lang  \
# 0                  I just got hired at Tesla! God is good.   en
# 1        tesla [mergrim mix] (Remastered 2020) - Spangl...   en
# 2        Tesla - Little Suzi https://t.co/9Lj4jvF8KR vi...   en
# ...

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3273947 entries, 0 to 3273946
# Data columns (total 11 columns):
#  #   Column          Dtype
# ---  ------          -----
#  0   created_at      object
#  1   id_str          int64
#  2   full_text       object
#  3   lang            object
#  4   user_name       object
#  5   user_full_name  object
#  6   user_verified   bool
#  7   hashtags        object
#  8   mentions        object
#  9   urls            object
#  10  media           object
# dtypes: bool(1), int64(1), object(9)
# memory usage: 277.9+ MB

# %%
df1 = df1.drop(['hashtags'], axis=1)

# %%
df1 = df1.drop(['mentions'], axis=1)

# %%
df1 = df1.drop(['urls'], axis=1)

# %%
df1 = df1.drop(['media'], axis=1)

# %%
df1
# Out:
#                         created_at               id_str  \
# 0        2020-06-01T22:59:51+00:00  1267591722126598144
# 1        2020-06-01T22:59:49+00:00  1267591711905026048
# 2        2020-06-01T22:58:40+00:00  1267591424628973574
# 3        2020-06-01T22:58:21+00:00  1267591344299683841
# 4        2020-06-01T22:57:35+00:00  1267591151487418372
# ...                            ...                  ...
# 3273942  2018-06-01T21:04:20+00:00  1002657120527966208
# 3273943  2018-06-01T21:02:59+00:00  1002656781955317760
# 3273944  2018-06-01T19:59:13+00:00  1002640730899210240
# 3273945  2018-06-01T19:53:19+00:00  1002639248602722304
# 3273946  2018-06-01T19:07:27+00:00  1002627705219584000
#
#                                                  full_text lang  \
# 0                  I just got hired at Tesla! God is good.   en
# 1        tesla [mergrim mix] (Remastered 2020) - Spangl...   en
# 2        Tesla - Little Suzi https://t.co/9Lj4jvF8KR vi...   en
# ...

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3273947 entries, 0 to 3273946
# Data columns (total 7 columns):
#  #   Column          Dtype
# ---  ------          -----
#  0   created_at      object
#  1   id_str          int64
#  2   full_text       object
#  3   lang            object
#  4   user_name       object
#  5   user_full_name  object
#  6   user_verified   bool
# dtypes: bool(1), int64(1), object(5)
# memory usage: 178.0+ MB

# %%
df1['lang'].unique()
# Out:
# array(['en', 'tr', 'fr', 'de', 'et', 'ht', 'cy', 'nl', 'es', 'tl', 'ca',
#        'in', 'da', 'no', 'pt', 'eu', 'sv', 'it', 'lv', 'und', 'vi', 'pl',
#        'hu', 'cs', 'ja', 'is', 'hi', 'lt'], dtype=object)

# %%
df1_en = df1[df1['lang'] == 'en']

# %%
df1_en
# Out:
#                         created_at               id_str  \
# 0        2020-06-01T22:59:51+00:00  1267591722126598144
# 1        2020-06-01T22:59:49+00:00  1267591711905026048
# 2        2020-06-01T22:58:40+00:00  1267591424628973574
# 3        2020-06-01T22:58:21+00:00  1267591344299683841
# 4        2020-06-01T22:57:35+00:00  1267591151487418372
# ...                            ...                  ...
# 3273942  2018-06-01T21:04:20+00:00  1002657120527966208
# 3273943  2018-06-01T21:02:59+00:00  1002656781955317760
# 3273944  2018-06-01T19:59:13+00:00  1002640730899210240
# 3273945  2018-06-01T19:53:19+00:00  1002639248602722304
# 3273946  2018-06-01T19:07:27+00:00  1002627705219584000
#
#                                                  full_text lang  \
# 0                  I just got hired at Tesla! God is good.   en
# 1        tesla [mergrim mix] (Remastered 2020) - Spangl...   en
# 2        Tesla - Little Suzi https://t.co/9Lj4jvF8KR vi...   en
# ...

# %%
df1_en['lang'].unique()
# Out:
# array(['en'], dtype=object)

# %%
df1_en.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3268523 entries, 0 to 3273946
# Data columns (total 7 columns):
#  #   Column          Dtype
# ---  ------          -----
#  0   created_at      object
#  1   id_str          int64
#  2   full_text       object
#  3   lang            object
#  4   user_name       object
#  5   user_full_name  object
#  6   user_verified   bool
# dtypes: bool(1), int64(1), object(5)
# memory usage: 177.7+ MB

# %%
df1_en.reset_index(drop=True)
# Out:
#                         created_at               id_str  \
# 0        2020-06-01T22:59:51+00:00  1267591722126598144
# 1        2020-06-01T22:59:49+00:00  1267591711905026048
# 2        2020-06-01T22:58:40+00:00  1267591424628973574
# 3        2020-06-01T22:58:21+00:00  1267591344299683841
# 4        2020-06-01T22:57:35+00:00  1267591151487418372
# ...                            ...                  ...
# 3268518  2018-06-01T21:04:20+00:00  1002657120527966208
# 3268519  2018-06-01T21:02:59+00:00  1002656781955317760
# 3268520  2018-06-01T19:59:13+00:00  1002640730899210240
# 3268521  2018-06-01T19:53:19+00:00  1002639248602722304
# 3268522  2018-06-01T19:07:27+00:00  1002627705219584000
#
#                                                  full_text lang  \
# 0                  I just got hired at Tesla! God is good.   en
# 1        tesla [mergrim mix] (Remastered 2020) - Spangl...   en
# 2        Tesla - Little Suzi https://t.co/9Lj4jvF8KR vi...   en
# ...

# %%
df1_en.to_csv("Scrapped and Cleaned.csv", index=False)

# %%
df1_en.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3268523 entries, 0 to 3273946
# Data columns (total 7 columns):
#  #   Column          Dtype
# ---  ------          -----
#  0   created_at      object
#  1   id_str          int64
#  2   full_text       object
#  3   lang            object
#  4   user_name       object
#  5   user_full_name  object
#  6   user_verified   bool
# dtypes: bool(1), int64(1), object(5)
# memory usage: 177.7+ MB

# %%
df1_en['date'] = df1_en['created_at'].str.split('T').str[0]
df1_en['time'] = df1_en['created_at'].str.split('T').str[1].str.split('+').str[0]
# Out:
# C:\Users\DIYA PATEL\AppData\Local\Temp\ipykernel_19944\31420703.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1_en['date'] = df1_en['created_at'].str.split('T').str[0]
# C:\Users\DIYA PATEL\AppData\Local\Temp\ipykernel_19944\31420703.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1_en['time'] = df1_en['created_at'].str.split('T').str[1].str.split('+').str[0]

# %%
df1_en
# Out:
#                         created_at               id_str  \
# 0        2020-06-01T22:59:51+00:00  1267591722126598144
# 1        2020-06-01T22:59:49+00:00  1267591711905026048
# 2        2020-06-01T22:58:40+00:00  1267591424628973574
# 3        2020-06-01T22:58:21+00:00  1267591344299683841
# 4        2020-06-01T22:57:35+00:00  1267591151487418372
# ...                            ...                  ...
# 3273942  2018-06-01T21:04:20+00:00  1002657120527966208
# 3273943  2018-06-01T21:02:59+00:00  1002656781955317760
# 3273944  2018-06-01T19:59:13+00:00  1002640730899210240
# 3273945  2018-06-01T19:53:19+00:00  1002639248602722304
# 3273946  2018-06-01T19:07:27+00:00  1002627705219584000
#
#                                                  full_text lang  \
# 0                  I just got hired at Tesla! God is good.   en
# 1        tesla [mergrim mix] (Remastered 2020) - Spangl...   en
# 2        Tesla - Little Suzi https://t.co/9Lj4jvF8KR vi...   en
# ...

# %%
df1_en.drop('created_at', axis=1, inplace=True)
# Out:
# C:\Users\DIYA PATEL\AppData\Local\Temp\ipykernel_19944\1395785934.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1_en.drop('created_at', axis=1, inplace=True)

# %%
df1_en
# Out:
#                       id_str  \
# 0        1267591722126598144
# 1        1267591711905026048
# 2        1267591424628973574
# 3        1267591344299683841
# 4        1267591151487418372
# ...                      ...
# 3273942  1002657120527966208
# 3273943  1002656781955317760
# 3273944  1002640730899210240
# 3273945  1002639248602722304
# 3273946  1002627705219584000
#
#                                                  full_text lang  \
# 0                  I just got hired at Tesla! God is good.   en
# 1        tesla [mergrim mix] (Remastered 2020) - Spangl...   en
# 2        Tesla - Little Suzi https://t.co/9Lj4jvF8KR vi...   en
# 3        New post: "Why Has Tesla Halved The Model Y De...   en
# 4        Meaning if you had a million units of Tesla yo...   en
# ...                                                    ...  ...
# 3273942  The best haiku in the world has only two sylla...   en
# 3273943  I love you hot\nI love you steamed\nI love you...   en
# ...

# %%
# convert date column to datetime type
df1_en['date_column'] = pd.to_datetime(df1_en['date'])

# filter rows with year 2020
df_2020 = df1_en[df1_en['date_column'].dt.year == 2020]
df_2019 = df1_en[df1_en['date_column'].dt.year == 2019]
df_2018 = df1_en[df1_en['date_column'].dt.year == 2018]
# Out:
# C:\Users\DIYA PATEL\AppData\Local\Temp\ipykernel_19944\438798295.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1_en['date_column'] = pd.to_datetime(df1_en['date'])

# %%
df_2020
# Out:
#                       id_str  \
# 0        1267591722126598144
# 1        1267591711905026048
# 2        1267591424628973574
# 3        1267591344299683841
# 4        1267591151487418372
# ...                      ...
# 1425463  1267553444706934784
# 1425464  1267551166864461826
# 1425465  1267549030785200133
# 1425466  1267534701889122305
# 1425467  1267533908490534912
#
#                                                  full_text lang  \
# 0                  I just got hired at Tesla! God is good.   en
# 1        tesla [mergrim mix] (Remastered 2020) - Spangl...   en
# 2        Tesla - Little Suzi https://t.co/9Lj4jvF8KR vi...   en
# 3        New post: "Why Has Tesla Halved The Model Y De...   en
# 4        Meaning if you had a million units of Tesla yo...   en
# ...                                                    ...  ...
# 1425463  Tesla Model 3 was California's best selling ca...   en
# 1425464  “Wow. Cops killed a black man. Look at this vi...   en
# ...

# %%
df_2019
# Out:
#                       id_str  \
# 1425468  1134957649450037248
# 1425469  1134957372948996096
# 1425470  1134957354712276995
# 1425471  1134956807577718784
# 1425472  1134956742062870528
# ...                      ...
# 1785689  1189713529453961218
# 1785690  1189713401536286723
# 1785691  1189713231109087234
# 1785692  1189712982059765760
# 1785693  1189712816481026048
#
#                                                  full_text lang  \
# 1425468  Why, when a hotel calls, are they callerid'd a...   en
# 1425469  I get my #Tesla #Model3 on Tuesday!!! I’m so e...   en
# 1425470  #tesla #supercharger in Evergreen Park, IL, US...   en
# 1425471  Great Earnings Numbers Push Facebook Stock Hig...   en
# 1425472  I can understand Tesla service mode being geof...   en
# ...                                                    ...  ...
# 1785689  #Tesla has too much favoritism between shifts....   en
# 1785690  Tesla Model 3 Survey: What Owners Think About ...   en
# ...

# %%
df_2018
# Out:
#                       id_str  \
# 1785694  1002686184626311171
# 1785695  1002686059606618115
# 1785696  1002686058205728773
# 1785697  1002685938299006979
# 1785698  1002685904568320001
# ...                      ...
# 3273942  1002657120527966208
# 3273943  1002656781955317760
# 3273944  1002640730899210240
# 3273945  1002639248602722304
# 3273946  1002627705219584000
#
#                                                  full_text lang  \
# 1785694  Tesla is the company to watch someday in the n...   en
# 1785695  tesla’s have a fuckin bio weapon defense mode,...   en
# 1785696  Is Tesla On The Verge Of Bankruptcy? https://t...   en
# 1785697  #Cost To Build a #Tesla #Model 3 #Is $ 28,000 ...   en
# 1785698  Some people bought #Tesla . However I bought S...   en
# ...                                                    ...  ...
# 3273942  The best haiku in the world has only two sylla...   en
# 3273943  I love you hot\nI love you steamed\nI love you...   en
# ...

# %%
df_2020.to_csv("2020.csv", index=False)

# %%
df_2019.to_csv("2019.csv", index=False)

# %%
df_2018.to_csv("2018.csv", index=False)
